# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Excel file
file_path = "OR_AE2_Project_Adjusted.xlsx" #Takes 108 seconds
df = pd.read_excel(file_path, engine='openpyxl')

# Display the first few rows
print(df.head())
# Out:
#    Site_Code Site_Type  Site_X  Site_Y  Site_Loc_GPs  Site_Loc_GP_List  \
# 0          2        ED   39785  114688            50            210000
# 1          2        ED   39785  114688            50            210000
# 2          2        ED   39785  114688            50            210000
# 3          2        ED   39785  114688            50            210000
# 4          2        ED   39785  114688            50            210000
#
#    Site_Pop_20miles  Pat_X   Pat_Y  Pat_Loc_GPs  Pat_Loc_GP_List  \
# 0           1814482  38971  114101            0                0
# 1           1814482  38971  114101            0                0
# 2           1814482  38971  114101            0                0
# 3           1814482  38971  114101            0                0
# 4           1814482  38971  114101            0                0
#
#   Drive_Distance_Miles Driving_Time_mins  Attendance_Type Age_Group Wait_Time  \
# ...

# %%
# Distribuzione del numero di attendances
sns.histplot(df['Number_Of_Attendances'], kde=True, bins=30)
plt.title('Distribuzione del numero di attendances')
plt.show()

# Distribuzione della distanza di guida
sns.histplot(df['Drive_Distance_Miles'], kde=False, bins=30)
plt.title('Distribuzione della distanza di guida')
plt.show()

# Distribuzione dei tempi di attesa
sns.histplot(df['Wait_Time'], kde=False, bins=15)
plt.title('Distribuzione dei tempi di attesa')
plt.show()

# %%
# Seleziona solo le colonne numeriche
numerical_df = df.select_dtypes(include=['number'])

# Calcola la matrice di correlazione
corr_matrix = numerical_df.corr()

# Heatmap delle correlazioni
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matrice di correlazione (solo variabili numeriche)')
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Scatterplot per i siti con punti più grandi
sns.scatterplot(x='Site_X', y='Site_Y', data=df, label='Siti', s=200, color='blue')

# Scatterplot per i pazienti
sns.scatterplot(x='Pat_X', y='Pat_Y', data=df, label='Pazienti', s=50, color='red')

plt.title('Distribuzione spaziale di siti e pazienti')
plt.legend()
plt.show()
